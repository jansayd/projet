# %%
import pyautogui
import time
import pyperclip

pyautogui.PAUSE = 2
pyautogui.alert("Vai começar, aperte OK e não mexa em nada")

# opção 1 - abrir navegador novo e entrar no chrome
# pyautogui.press("winleft")
# pyautogui.write("chrome")
# pyautogui.press("enter")

# opção 2 - abrir uma nova aba
pyautogui.hotkey('ctrl', 't')

# abrir drive
# ensinar aqui o write
link = "https://drive.google.com/drive/my-drive"
pyperclip.copy(link)
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
time.sleep(5)

# baixar base de dados atualizada
pyautogui.click(363, 628, clicks=2)
pyautogui.click(360, 396)
pyautogui.click(1124, 181)
pyautogui.click(937, 626)
time.sleep(10)

# %%
import pandas as pd

df = pd.read_excel(r"C:\Users\Lucas\Downloads\Vendas.xlsx")
display(df)
faturamento = df['Valor Final'].sum()
qtde_produtos = df['Quantidade'].sum()
# Out:
#       Código Venda       Data                       ID Loja  \
# 0            65014 2019-12-01              Shopping Morumbi
# 1            65014 2019-12-01              Shopping Morumbi
# 2            65016 2019-12-01             Iguatemi Campinas
# 3            65016 2019-12-01             Iguatemi Campinas
# 4            65017 2019-12-01            Shopping SP Market
# ...            ...        ...                           ...
# 3490         67435 2019-12-13             Shopping Eldorado
# 3491         67436 2019-12-13   Palladium Shopping Curitiba
# 3492         67436 2019-12-13   Palladium Shopping Curitiba
# 3493         67437 2019-12-13  Novo Shopping Ribeirão Preto
# 3494         67437 2019-12-13  Novo Shopping Ribeirão Preto
#
#                    Produto  Quantidade  Valor Unitário  Valor Final
# 0           Sunga Listrado           5             114          570
# 1          Casaco Listrado           1             269          269
# 2          Sapato Listrado           2             363          726
# 3                   Casaco           1             250          250
# 4               Gorro Liso           3              92          276
# ...                    ...         ...             ...          ...
# 3490                 Sunga           1             100          100
# 3491  Camisa Gola V Xadrez           2             107          214
# 3492         Camiseta Liso           1             187          187
# 3493           Cinto Linho           1             248          248
# 3494          Tênis Xadrez           1             259          259
#
# [3495 rows x 7 columns]

# %%
import pyperclip

# abrir aba gmail
pyautogui.hotkey('ctrl', 't')
pyautogui.write("mail.google.com")
pyautogui.press('enter')
time.sleep(5)

# clicar em escrever email
pyautogui.click(62, 201)

# preencher informações do e-mail
pyautogui.write('jkfs@hotmail.com')
pyautogui.press('tab')
pyautogui.press('tab')
assunto = "Relatório de Vendas de Ontem"
pyperclip.copy(assunto)
pyautogui.hotkey("ctrl", 'v')
pyautogui.press("tab")
texto = f"""
Prezados, bom dia

O faturamento de ontem foi de: R${faturamento:,.2f}
A quantidade de produtos foi de: {qtde_produtos:,}

Abs
Jan Kleber"""
pyperclip.copy(texto)
pyautogui.hotkey("ctrl", 'v')

# enviar e-mail
pyautogui.hotkey('ctrl', 'enter')

# avisar que acabou
pyautogui.alert("Fim da Automação. Jan computador já voltou a ser seu")
# Out:
# 'OK'
